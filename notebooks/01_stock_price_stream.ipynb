# %%
import pandas as pd
pd.read_csv("../data/raw/prices/latest_price.csv").head()
# Out:
#          Open        High         Low       Close     Volume  Dividends  \
# 0  272.149994  274.600006  269.899994  273.670013  144599200        0.0
#
#    Stock Splits
# 0           0.0
